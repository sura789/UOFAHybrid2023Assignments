# %% [markdown]
# ## Objective

# %% [markdown]
# This homework sheet will help reviewing the basic concepts associated with classification models. Please review the lectures, suggested readings, and additional resources before getting started on the HW.

# %% [markdown]
# **Some questions in this assignment will require you to conduct independent research beyond the material covered in the recorded content.**

# %% [markdown]
# **Questions**

# %% [markdown]
# This homework is divided into two main parts. First, a conceptual component will review the basic concepts related to classification models. The second part of the homework is mostly intended to be a brief introduction to fitting and analyzing classifiers in `Python`. Several of these questions are modified from James et al. (2021).

# %% [markdown]
# Marks Distribution
#
# | Question      | Marks |
# | ----------- | ----------- |
# | 1a    |    0.25  |
# | 1b    |    0.25   |
# | 1c    |    0.25   |
# | 1d     |   0.25    |
# | 2a     |    0.50  |
# | 2b     |    0.50  |
# | 3     |     1 |
# | 4a    |    1  |
# | 4b    |    1   |
# | 4c    |     0.5  |
# | 4d     |    1   |
# | 4e     |    1  |
# | 4f     |    1   |
# | 4g     |     0.25  |
# | 4h     |     0.25  |
# | 5a    |     1 |
# | 5b    |     1  |
# | 5c    |     1  |
# | 5d     |     1  |
# | 5e     |     1  |
# | 5f     |     1  |

# %% [markdown]
# ## Conceptual Questions

# %% [markdown]
# ### Q1. Let’s examine the differences between LDA and QDA.

# %% [markdown]
# #### a) If the Bayes decision boundary is linear, do we expect LDA or QDA to perform better on the training set? What about in the test set?

# %% [markdown]
#  Answer:
#
# Provide answer in the markdown cell
#
# In the context of classification, Linear Discriminant Analysis (LDA) and Quadratic Discriminant Analysis (QDA) are two commonly used algorithms that assume different distributions for the data.
#
# When the Bayes decision boundary (the optimal decision boundary that minimizes misclassification) is linear, LDA tends to perform better on the training set compared to QDA. This is because LDA assumes that the class-conditional densities (i.e., the distribution of features given the class) for each class are multivariate normal and have the same covariance matrix. Under this assumption, LDA tries to find a linear decision boundary that best separates the classes. When the true underlying distribution is close to a linear separation, LDA can effectively model the data and make accurate predictions.
#
# On the other hand, QDA does not make the assumption of equal covariance matrices for the class-conditional densities. Instead, it allows for different covariance matrices for each class. This added flexibility can be an advantage when the data distribution is not close to linear, and the true decision boundary is better approximated by a quadratic or curved boundary. However, in cases where the underlying decision boundary is close to linear, QDA may overfit the training data by fitting more complex quadratic boundaries to the data, leading to reduced generalization performance on the test set.
#
# In summary, if the Bayes decision boundary is linear, LDA is expected to perform better than QDA on both the training set and the test set due to its simplicity and tendency to generalize well in such situations. QDA might be more prone to overfitting and may not perform as well on the test set.

# %% [markdown]
# #### b) If the Bayes decision boundary is non-linear, do we expect LDA or QDA to perform better on the training set? On the test set?

# %% [markdown]
# Answer:
#
# Provide answer in the markdown cell
#
# If the Bayes decision boundary is non-linear, we expect Quadratic Discriminant Analysis (QDA) to perform better than Linear Discriminant Analysis (LDA) on both the training set and the test set.
#
# When the underlying decision boundary is non-linear, LDA's assumption of equal covariance matrices for each class becomes limiting. LDA assumes that the class-conditional densities are multivariate normal and share the same covariance matrix for all classes. This assumption effectively restricts LDA to linear decision boundaries. As a result, LDA may struggle to capture the complex non-linear relationships between features and classes, leading to suboptimal performance.
#
# On the other hand, QDA allows for different covariance matrices for each class, providing greater flexibility in modeling non-linear decision boundaries. By accommodating more complex shapes for the decision boundary, QDA can better capture the underlying data distribution and improve its performance in scenarios with non-linear decision boundaries.
#
# Therefore, if the true decision boundary is non-linear, QDA is expected to outperform LDA on both the training set and the test set. It can better fit the training data and generalize well to new, unseen data with non-linear characteristics. However, it is essential to be cautious with overfitting in cases where the training data size is small and the complexity of the decision boundary is high. Regularization techniques can be employed in QDA to mitigate overfitting and enhance generalization.

# %% [markdown]
# #### c)In general, as the sample size n increases, do we expect the test prediction accuracy of QDA relative to LDA to improve, decline, or be unchanged? Why?

# %% [markdown]
# Answer:
#
# Provide answer in the markdown cell
#
# As the sample size (n) increases, we expect the test prediction accuracy of QDA relative to LDA to improve. The reason behind this improvement lies in how each method handles the estimation of parameters and the effect of sample size on the performance of these algorithms.
#
# 1. **Parameter Estimation:**
#    - LDA: Linear Discriminant Analysis assumes equal covariance matrices for all classes and estimates the covariance matrix based on the pooled covariance of the data. As the sample size increases, the estimation of the covariance matrix becomes more accurate and less prone to bias.
#    - QDA: Quadratic Discriminant Analysis allows for different covariance matrices for each class. With a larger sample size, QDA has more data points to estimate each covariance matrix accurately, leading to better representations of the class-conditional densities.
#
# 2. **Overfitting and Bias-Variance Trade-off:**
#    - LDA: LDA's assumption of equal covariance matrices and linear decision boundaries can lead to underfitting in scenarios where the true decision boundary is non-linear. With a larger sample size, the risk of underfitting decreases due to better parameter estimation, but it may still be limited by its linearity assumption.
#    - QDA: QDA's flexibility to model non-linear decision boundaries can lead to better generalization performance as the sample size increases. It can capture more complex relationships between features and classes, reducing the risk of underfitting, and potentially offering better accuracy on the test set.
#
# 3. **High-dimensional Data:**
#    - In high-dimensional data, QDA may face challenges due to the large number of parameters to estimate with limited data. However, as the sample size increases, the impact of this issue diminishes, and QDA can better exploit the additional information to improve predictions.
#
# In summary, as the sample size increases, QDA tends to benefit more than LDA in terms of improved test prediction accuracy. The increased data availability allows QDA to estimate parameters more accurately, take advantage of its flexibility in modeling non-linear decision boundaries, and provide better generalization on the test set compared to LDA. However, it's important to note that the actual performance improvement may vary depending on the specific characteristics of the dataset and the true underlying data distribution.

# %% [markdown]
# #### d)True or False:
# Even if the Bayes decision boundary for a given problem is linear, we will probably achieve a superior test error rate using QDA rather than LDA because QDA is flexible enough to model a linear decision boundary.

# %% [markdown]
# Answer:
#
# Provide answer in the markdown cell
#
# False.
#
# If the Bayes decision boundary for a given problem is linear, Linear Discriminant Analysis (LDA) is expected to perform better than Quadratic Discriminant Analysis (QDA) in terms of test error rate. The reason is that when the true underlying decision boundary is linear, LDA, which assumes a linear decision boundary and equal covariance matrices for all classes, is better suited for the task.
#
# QDA allows for more flexibility by assuming a quadratic decision boundary and allowing different covariance matrices for each class. While this added flexibility can be beneficial when the true decision boundary is non-linear, it can lead to overfitting when the true decision boundary is linear. In such cases, QDA may fit overly complex quadratic decision boundaries to the data, leading to reduced generalization performance on unseen data, i.e., higher test error rate.
#
# On the other hand, LDA's simplicity and linearity assumption are advantageous when the true decision boundary is indeed linear. LDA is more likely to find an optimal linear decision boundary that effectively separates the classes and generalizes well to the test set.
#
# So, in the scenario where the Bayes decision boundary is linear, LDA is expected to achieve a superior test error rate compared to QDA.

# %% [markdown]
# ### Q2) In relation to the odds and the Default dataset

# %% [markdown]
# #### a) On average, what fraction of people with an odds of `0.37` of defaulting on their credit card payment will in fact default?

# %%
# BEGIN SOLUTION

def calculate_actual_default_fraction(odds):
    # Calculate the probability of defaulting from the given odds
    probability_default = odds / (1 + odds)

    # Calculate the fraction of people who will actually default
    actual_default_fraction = probability_default

    return actual_default_fraction

# Given odds of 0.37
odds_of_default = 0.37

# Calculate the fraction of people who will actually default
fraction_of_people_default = calculate_actual_default_fraction(odds_of_default)

print("On average, approximately {:.1%} of people with an odds of {} of defaulting on their credit card payment will actually default.".format(fraction_of_people_default, odds_of_default))

# END SOLUTION
# Out:
# On average, approximately 27.0% of people with an odds of 0.37 of defaulting on their credit card payment will actually default.

# %% [markdown]
# Provide answer in the markdown cell
#
# To determine the fraction of people with an odds of 0.37 of defaulting on their credit card payment who will actually default, we need to use the relationship between odds and probabilities.
#
# The odds of an event A are defined as the ratio of the probability of A occurring to the probability of A not occurring. If p is the probability of A occurring, then the odds of A are given by:
#
# Odds(A) = p / (1 - p)
#
# We are given that the odds of defaulting on their credit card payment is 0.37. Let p_default be the probability of defaulting:
#
# Odds(default) = p_default / (1 - p_default) = 0.37
#
# To find the probability of defaulting (p_default), we rearrange the equation:
#
# p_default = Odds(default) / (1 + Odds(default))
#
# p_default = 0.37 / (1 + 0.37)
#
# p_default = 0.37 / 1.37
#
# p_default ≈ 0.270
#
# So, on average, approximately 27.0% of people with an odds of 0.37 of defaulting on their credit card payment will actually default.

# %% [markdown]
# #### b) Suppose that an individual has a `16%` chance of defaulting on their credit card payment. What are the odds that they will default?

# %%
# BEGIN SOLUTION

def calculate_odds_from_probability(probability):
    # Calculate the odds of defaulting from the given probability
    odds_default = probability / (1 - probability)

    return odds_default

# Given probability of defaulting is 16%
probability_default = 0.16

# Calculate the odds of defaulting
odds_of_default = calculate_odds_from_probability(probability_default)

print("The odds that an individual will default on their credit card payment given a 16% chance of default are: {:.2f}".format(odds_of_default))

# END SOLUTION
# Out:
# The odds that an individual will default on their credit card payment given a 16% chance of default are: 0.19

# %% [markdown]
# Answer:
# Provide answer in the markdown cell
#
# To calculate the odds that an individual will default on their credit card payment given a 16% chance of default, we can use the relationship between odds and probabilities as follows:
#
# The probability of defaulting (p_default) is given as 16% (0.16). The odds of defaulting (Odds(default)) can be calculated as:
#
# Odds(default) = p_default / (1 - p_default)
#
# Substitute the value of p_default:
#
# Odds(default) = 0.16 / (1 - 0.16)
#
# Odds(default) = 0.16 / 0.84
#
# Odds(default) ≈ 0.1905
#
# The calculated value, approximately 0.1905, represents the odds that an individual will default on their credit card payment. It tells us that for every one individual who defaults, there are approximately 0.1905 individuals who do not default (but could have). Alternatively, we can say that there is a 0.1905 or 19.05% chance that an individual will default, given the initial probability of 16%. This can be interpreted as the likelihood of defaulting relative to not defaulting.

# %% [markdown]
# #### Q3. Suppose that we take a data set, divide it into equally sized training and test sets, and then try out two different classification procedures. First, we use logistic regression and get an error rate of `20%` on the training data and `30%` on the test data. Next we use 1-nearest neighbors (i.e. `K=1`) and get an average error rate (averaged over both test and training data sets) of `18%`. Based on these results, which method should we prefer to use for classification of new observations? Why?

# %% [markdown]
# Answer:
# Provide answer in the markdown cell
#
# To determine which method is preferable for classification of new observations, we need to consider their performance on both the training and test data sets. In this case, we have two classification procedures: logistic regression and 1-nearest neighbor (K=1). Let's analyze their performance:
#
# 1. **Logistic Regression:**
#    - Error Rate on Training Data: 20%
#    - Error Rate on Test Data: 30%
#
# 2. **1-Nearest Neighbor (K=1):**
#    - Average Error Rate (Training + Test Data): 18%
#
# Now, let's interpret the results:
#
# - Logistic Regression:
#   - The error rate on the training data (20%) is lower than the error rate on the test data (30%). This indicates that logistic regression is likely overfitting the training data to some extent, as it performs better on the data it was trained on compared to unseen data.
#   - The higher error rate on the test data suggests that logistic regression may not be generalizing well to new, unseen observations.
#
# - 1-Nearest Neighbor (K=1):
#   - The average error rate (18%) is lower than both the error rates of logistic regression on both the training and test data.
#   - 1-Nearest Neighbor is a simple and flexible method that adapts well to the training data. Since it essentially memorizes the training data, it can potentially perform well on both the training and test data if the underlying data distribution is not too complex.
#
# Based on the results, the 1-Nearest Neighbor method appears to be more preferable for the classification of new observations. It has a lower average error rate, indicating better generalization to unseen data compared to logistic regression. While logistic regression can be powerful in certain scenarios, it seems to be overfitting the training data, which might result in poorer performance on unseen test data.
#
# However, it's essential to interpret these results with caution. The choice of the best method ultimately depends on the specific characteristics of the data and the problem at hand. In some cases, logistic regression might still be a suitable choice with proper regularization techniques to avoid overfitting. Experimentation and evaluation on different data sets or cross-validation can further validate the performance of these methods.

# %% [markdown]
# ## Applied

# %% [markdown]
# #### 4) This question should be answered using the `Weekly` data set, which is part of the `ISLR2` package. This data is similar in nature to the `Smarket` data examined in the book (Ch4, lab). First, load the dataset:
#
#
#  https://book.huihoo.com/introduction-to-statistical-learning/data.html
#
#  Link for getting rdataset into python:
#  https://www.statsmodels.org/dev/datasets/statsmodels.datasets.get_rdataset.html
#
#
#  By using the below command you can get the ISLR dataset
#  `sm.datasets.get_rdataset('Weekly', 'ISLR').data`

# %% [markdown]
# #### a) Produce some numerical and graphical summaries of the `Weekly` data. Can you identify any patterns? Hint: examine the __correlation__ between predictors.

# %% [markdown]
# **Importing Libraries:**

# %%
#IMPORT LIBRARIES

import statsmodels.api as sm
import numpy as np
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Loading dataset:**

# %%
#READ Weekly DATASET USING THE CODE GIVEN IN QUESTION 4

data = sm.datasets.get_rdataset('Weekly', 'ISLR').data

# %%
#PERFORM PRE PROCESSING OF DATA IF REQUIRED ( OBSERVE THE DATASET AND ITS VALUES CAREFULLY)

# BEGIN SOLUTION

# Examine the data and its structure:

# Display the first few rows of the data

data.head(5)
# Out:
#    Year   Lag1   Lag2   Lag3   Lag4   Lag5    Volume  Today Direction
# 0  1990  0.816  1.572 -3.936 -0.229 -3.484  0.154976 -0.270      Down
# 1  1990 -0.270  0.816  1.572 -3.936 -0.229  0.148574 -2.576      Down
# 2  1990 -2.576 -0.270  0.816  1.572 -3.936  0.159837  3.514        Up
# 3  1990  3.514 -2.576 -0.270  0.816  1.572  0.161630  0.712        Up
# 4  1990  0.712  3.514 -2.576 -0.270  0.816  0.153728  1.178        Up

# %%
# Get summary statistics of the data

data.describe()
# Out:
#               Year         Lag1         Lag2         Lag3         Lag4  \
# count  1089.000000  1089.000000  1089.000000  1089.000000  1089.000000
# mean   2000.048669     0.150585     0.151079     0.147205     0.145818
# std       6.033182     2.357013     2.357254     2.360502     2.360279
# min    1990.000000   -18.195000   -18.195000   -18.195000   -18.195000
# 25%    1995.000000    -1.154000    -1.154000    -1.158000    -1.158000
# 50%    2000.000000     0.241000     0.241000     0.241000     0.238000
# 75%    2005.000000     1.405000     1.409000     1.409000     1.409000
# max    2010.000000    12.026000    12.026000    12.026000    12.026000
#
#               Lag5       Volume        Today
# count  1089.000000  1089.000000  1089.000000
# mean      0.139893     1.574618     0.149899
# std       2.361285     1.686636     2.356927
# min     -18.195000     0.087465   -18.195000
# 25%      -1.166000     0.332022    -1.154000
# 50%       0.234000     1.002680     0.241000
# ...

# %%
# Check the data types of each column

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1089 entries, 0 to 1088
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       1089 non-null   int64
#  1   Lag1       1089 non-null   float64
#  2   Lag2       1089 non-null   float64
#  3   Lag3       1089 non-null   float64
#  4   Lag4       1089 non-null   float64
#  5   Lag5       1089 non-null   float64
#  6   Volume     1089 non-null   float64
#  7   Today      1089 non-null   float64
#  8   Direction  1089 non-null   object
# dtypes: float64(7), int64(1), object(1)
# memory usage: 76.7+ KB

# %%
# Checking for Missing Values:

print(data.isnull().sum())
# Out:
# Year         0
# Lag1         0
# Lag2         0
# Lag3         0
# Lag4         0
# Lag5         0
# Volume       0
# Today        0
# Direction    0
# dtype: int64

# %%
# Direction Column is object type, so one hot encoding is required.

# Perform label encoding for the 'Direction' column

label_encoder = LabelEncoder()
data['Direction'] = label_encoder.fit_transform(data['Direction'])

# %%
data
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5    Volume  Today  Direction
# 0     1990  0.816  1.572 -3.936 -0.229 -3.484  0.154976 -0.270          0
# 1     1990 -0.270  0.816  1.572 -3.936 -0.229  0.148574 -2.576          0
# 2     1990 -2.576 -0.270  0.816  1.572 -3.936  0.159837  3.514          1
# 3     1990  3.514 -2.576 -0.270  0.816  1.572  0.161630  0.712          1
# 4     1990  0.712  3.514 -2.576 -0.270  0.816  0.153728  1.178          1
# ...    ...    ...    ...    ...    ...    ...       ...    ...        ...
# 1084  2010 -0.861  0.043 -2.173  3.599  0.015  3.205160  2.969          1
# 1085  2010  2.969 -0.861  0.043 -2.173  3.599  4.242568  1.281          1
# 1086  2010  1.281  2.969 -0.861  0.043 -2.173  4.835082  0.283          1
# 1087  2010  0.283  1.281  2.969 -0.861  0.043  4.454044  1.034          1
# 1088  2010  1.034  0.283  1.281  2.969 -0.861  2.707105  0.069          1
#
# [1089 rows x 9 columns]

# %%
# After doing label encoding check the data types

data.info()

# END SOLUTION
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1089 entries, 0 to 1088
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       1089 non-null   int64
#  1   Lag1       1089 non-null   float64
#  2   Lag2       1089 non-null   float64
#  3   Lag3       1089 non-null   float64
#  4   Lag4       1089 non-null   float64
#  5   Lag5       1089 non-null   float64
#  6   Volume     1089 non-null   float64
#  7   Today      1089 non-null   float64
#  8   Direction  1089 non-null   int64
# dtypes: float64(7), int64(2)
# memory usage: 76.7 KB

# %%
# BEGIN SOLUTION

# Scaling/Normalizing Numerical Features

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Select the numerical columns to scale (excluding 'Year' column if it's not useful for modeling)

numerical_columns = ['Lag1', 'Lag2', 'Lag3', 'Lag4', 'Lag5', 'Volume', 'Today', 'Direction']
data[numerical_columns] = scaler.fit_transform(data[numerical_columns])

# END SOLUTION

# %%
data.head()
# Out:
#    Year      Lag1      Lag2      Lag3      Lag4      Lag5    Volume     Today  \
# 0  1990  0.629066  0.654082  0.471824  0.594487  0.486781  0.007306  0.593131
# 1  1990  0.593131  0.629066  0.654082  0.471824  0.594487  0.006613  0.516826
# 2  1990  0.516826  0.593131  0.629066  0.654082  0.471824  0.007832  0.718342
# 3  1990  0.718342  0.516826  0.593131  0.629066  0.654082  0.008026  0.625625
# 4  1990  0.625625  0.718342  0.516826  0.593131  0.629066  0.007171  0.641044
#
#    Direction
# 0        0.0
# 1        0.0
# 2        1.0
# 3        1.0
# 4        1.0

# %%
# BEGIN SOLUTION

# Calculate the correlation matrix
correlation_matrix = data.corr()

# Display the correlation matrix
correlation_matrix
# Out:
#                Year      Lag1      Lag2      Lag3      Lag4      Lag5  \
# Year       1.000000 -0.032289 -0.033390 -0.030006 -0.031128 -0.030519
# Lag1      -0.032289  1.000000 -0.074853  0.058636 -0.071274 -0.008183
# Lag2      -0.033390 -0.074853  1.000000 -0.075721  0.058382 -0.072499
# Lag3      -0.030006  0.058636 -0.075721  1.000000 -0.075396  0.060657
# Lag4      -0.031128 -0.071274  0.058382 -0.075396  1.000000 -0.075675
# Lag5      -0.030519 -0.008183 -0.072499  0.060657 -0.075675  1.000000
# Volume     0.841942 -0.064951 -0.085513 -0.069288 -0.061075 -0.058517
# Today     -0.032460 -0.075032  0.059167 -0.071244 -0.007826  0.011013
# Direction -0.022200 -0.050004  0.072696 -0.022913 -0.020549 -0.018168
#
#              Volume     Today  Direction
# Year       0.841942 -0.032460  -0.022200
# Lag1      -0.064951 -0.075032  -0.050004
# Lag2      -0.085513  0.059167   0.072696
# Lag3      -0.069288 -0.071244  -0.022913
# Lag4      -0.061075 -0.007826  -0.020549
# ...

# %%
# Pairplot to visualize the relationships between predictors
sns.pairplot(data)
plt.show()

# %% [markdown]
# - There is a strong positive correlation between Year and Volume. In other words, if the value of Year increases, the value of Volume is likely to increase as well.
# - There is a strong positive correlation between Today and Direction. In other words, if the value of Today increases, the value of Direction is likely to increase.
#
# Overall, the pair plot shows that there are a few strong correlations between the variables. These correlations could be used to identify potential relationships between the variables.

# %%
# Heatmap to visualize the correlation matrix

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# END SOLUTION

# %% [markdown]
# 1. **Volume and Year (0.84)**: This correlation suggests a strong positive relationship between the volume and the year. A value close to 1 indicates that as the years increase, the trading volume tends to increase as well.
#
# 2. **Today and Direction (0.72)**: This correlation indicates a moderate positive relationship between the current day ("Today") and the direction ("Direction"). A value of around 0.72 suggests that days with positive returns on "Today" are more likely to have a positive direction ("up" movement) and days with negative returns are more likely to have a negative direction ("down" movement).
#
# 3. **Year and Lag1 (-0.032289)**: Year and Lag1 have a weak negative correlation of approximately -0.032. The correlation suggests that there is very small relationship between Year and Lag1.
#
# 4. **Volume and Today (-0.033078)**: Volume and Today have a weak negative correlation of approximately -0.033. The correlation suggests that there is very small relationship between volume and today.
#
# 5. **Lag1, Lag2, Lag3, Lag4, and Lag5**: The Lag variables (Lag1 to Lag5) show relatively weak correlations with each other and with other variables.

# %% [markdown]
# You can refer to the `seaborn` library documentation to attempt this problem: https://seaborn.pydata.org/

# %% [markdown]
# #### b) Use the full data set to perform a logistic regression with Direction as the response and the five `lag` variables plus `Volume` as predictors. Use the summary function to print the results. Do any of the predictors appear to be statistically significant? If so, which ones? Use the statsmodels to construct the classifier.
#
# Link: https://www.statsmodels.org/

# %%
#BEGIN SOLUTION

# Create the design matrix with predictors and response variable
X = data[['Lag1', 'Lag2', 'Lag3', 'Lag4', 'Lag5', 'Volume']]
y = data['Direction']

# Add a constant column to the predictors matrix for the intercept term in the logistic regression
X = sm.add_constant(X)

# END SOLUTION

# %%
# BEGIN SOLUTION

# Create the logistic regression model
logit_model = sm.Logit(y, X)

# Fit the model to the data
result = logit_model.fit()

# Print the summary of the logistic regression model
print(result.summary())

# END SOLUTION
# Out:
# Optimization terminated successfully.
#          Current function value: 0.682441
#          Iterations 4
#                            Logit Regression Results
# ...
# Dep. Variable:              Direction   No. Observations:                 1089
# Model:                          Logit   Df Residuals:                     1082
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 09 Aug 2023   Pseudo R-squ.:                0.006580
# Time:                        17:24:19   Log-Likelihood:                -743.18
# converged:                       True   LL-Null:                       -748.10
# Covariance Type:            nonrobust   LLR p-value:                    0.1313
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0136      1.168      0.868      0.385      -1.275       3.302
# ...

# %% [markdown]
# In the logistic regression results provided, the statistical significance of each predictor is determined by the p-value (P>|z|) associated with each coefficient estimate. A lower p-value indicates greater statistical significance, implying that the predictor has a significant impact on the response variable (Direction) and is likely not due to chance.
#
# Looking at the p-values for each predictor:
#
# - `const`: The constant term doesn't appear to be statistically significant (p-value = 0.385), which means it may not have a significant impact on the response variable.
#
# - `Lag1`: The Lag1 variable also doesn't appear to be statistically significant (p-value = 0.118), suggesting it may not have a significant effect on the response.
#
# - `Lag2`: The Lag2 variable appears to be statistically significant (p-value = 0.030). Its low p-value indicates that it likely has a significant impact on the response variable.
#
# - `Lag3`: The Lag3 variable doesn't appear to be statistically significant (p-value = 0.547), suggesting it may not have a significant effect on the response.
#
# - `Lag4`: The Lag4 variable doesn't appear to be statistically significant (p-value = 0.294), indicating it may not have a significant impact on the response.
#
# - `Lag5`: The Lag5 variable doesn't appear to be statistically significant (p-value = 0.583), suggesting it may not have a significant effect on the response.
#
# - `Volume`: The Volume variable also doesn't appear to be statistically significant (p-value = 0.538), indicating it may not have a significant impact on the response.
#
# In summary, among the predictors, only Lag2 appears to be statistically significant at a conventional significance level (e.g., p-value < 0.05). The other predictors do not show significant relationships with the response variable, Direction, based on the available data and the logistic regression model used.

# %% [markdown]
# #### C) Compute the confusion matrix and overall fraction of correct predictions. Explain what the confusion matrix is telling you about the types of mistakes made by logistic regression.

# %%
# BEGIN SOLUTION

# Make predictions using the fitted model
predictions = (result.predict(X) >= 0.5).astype(int)

# %%
# Compute the classification report
report = classification_report(y, predictions)

print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.11      0.18       484
#          1.0       0.56      0.92      0.70       605
#
#     accuracy                           0.56      1089
#    macro avg       0.55      0.52      0.44      1089
# weighted avg       0.55      0.56      0.47      1089

# %%
# Create the confusion matrix

cm = confusion_matrix(y, predictions)
print("Confusion Matrix:")
print(cm)

# END SOLUTION
# Out:
# Confusion Matrix:
# [[ 54 430]
#  [ 48 557]]

# %%
# BEGIN SOLUTION

# Create the confusion matrix
cm = confusion_matrix(y, predictions)

# Create a custom color palette
cmap = sns.light_palette("green", as_cmap=True)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, cmap=cmap, fmt="d", cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix', fontsize=14)
plt.show()

# END SOLUTION

# %%
# Calculate the overall accuracy
accuracy = accuracy_score(y, predictions)
print("\nOverall Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Overall Accuracy: 56.11%

# %% [markdown]
# **Observations:**

# %% [markdown]
# - True Negatives (TN): The top-left cell (54) represents the number of observations that are correctly predicted as the negative class (class 0). In this case, there are 54 instances where the logistic regression correctly identified "Down" (class 0) as "Down."
#
# - False Positives (FP): The top-right cell (430) represents the number of observations that are incorrectly predicted as the positive class (class 1) when their true label is negative (class 0). In this case, there are 430 instances where the logistic regression falsely predicted "Up" (class 1) when the true label was "Down" (class 0). These are also known as Type I errors or false alarms.
#
# - False Negatives (FN): The bottom-left cell (48) represents the number of observations that are incorrectly predicted as the negative class (class 0) when their true label is positive (class 1). In this case, there are 48 instances where the logistic regression falsely predicted "Down" (class 0) when the true label was "Up" (class 1). These are also known as Type II errors or missed opportunities.
#
# - True Positives (TP): The bottom-right cell (557) represents the number of observations that are correctly predicted as the positive class (class 1). In this case, there are 557 instances where the logistic regression correctly identified "Up" (class 1) as "Up."
#
# Interpreting the confusion matrix:
#
# - The model correctly predicted 54 observations as "Down" (true negatives).
# The model incorrectly predicted 430 observations as "Up" when they were actually "Down" (false positives).
# - The model incorrectly predicted 48 observations as "Down" when they were actually "Up" (false negatives).
# - The model correctly predicted 557 observations as "Up" (true positives).
#
# The confusion matrix provides insights into the types of mistakes made by the logistic regression classifier. In this case, the classifier has a relatively high number of false positives (430) compared to false negatives (48), indicating that it tends to make more Type I errors (false alarms) than Type II errors (missed opportunities). Understanding these error types helps to assess the strengths and weaknesses of the model and provides valuable information for model improvement and fine-tuning. Depending on the problem's context and costs associated with different errors, you can adjust the classification threshold or explore other techniques to improve the model's performance.

# %% [markdown]
# #### d) Now fit the logistic regression model using a training data period from __1990 to 2008__, with `Lag2` as the only predictor. Compute the confusion matrix and the overall fraction of correct predictions for the held out data (that is, the data from __2009 and 2010__).

# %%
# BEGIN SOLUTION

# Filter the data for the training period (1990 to 2008)
train_data = data[data['Year'] <= 2008]

# Filter the data for the test period (2009 and 2010)
test_data = data[data['Year'] >= 2009]

# Create the design matrix with Lag2 as the predictor for training data
X_train = train_data[['Lag2']]
y_train = train_data['Direction']

# Create the logistic regression model and fit it to the training data
logit_model = LogisticRegression()
logit_model.fit(X_train, y_train)

# Prepare the design matrix for the test data
X_test = test_data[['Lag2']]

# END SOLUTION

# %%
# BEGIN SOLUTION

# Make predictions on the test data
predictions = logit_model.predict(X_test)

# Create the confusion matrix
cm = confusion_matrix(test_data['Direction'], predictions)

print("Confusion Matrix:")
print(cm)

# Compute the classification report
report = classification_report(test_data['Direction'], predictions)

print("\n\nClassification Report:")
print(report)

# END SOLUTION
# Out:
# Confusion Matrix:
# [[ 2 41]
#  [ 1 60]]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.05      0.09        43
#          1.0       0.59      0.98      0.74        61
#
#     accuracy                           0.60       104
#    macro avg       0.63      0.52      0.41       104
# weighted avg       0.62      0.60      0.47       104

# %%
#BEGIN SOLUTION

# Calculate the overall accuracy
accuracy = accuracy_score(test_data['Direction'], predictions)

# Create a custom color palette
cmap = sns.light_palette("orange", as_cmap=True)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, cmap=cmap, fmt="d", cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix', fontsize=14)
plt.show()

# Calculate the overall accuracy
accuracy = accuracy_score(test_data['Direction'], predictions)
print("\n\nOverall Accuracy: {:.2f}%".format(accuracy * 100))

#END SOLUTION
# Out:
# Overall Accuracy: 59.62%

# %% [markdown]
# The interpretation of the confusion matrix:
#
# True Positives (TP) = 60
# False Positives (FP) = 41
# False Negatives (FN) = 1
# True Negatives (TN) = 2
#
# Now, let's compute the overall fraction of correct predictions (accuracy):

# %%
# Given confusion matrix
confusion_matrix = [[2, 41], [1, 60]]

# Calculate overall accuracy
TN, FP, FN, TP = confusion_matrix[0][0], confusion_matrix[0][1], confusion_matrix[1][0], confusion_matrix[1][1]
total_predictions = TP + FP + FN + TN
accuracy = (TP + TN) / total_predictions

print("Confusion Matrix:")
print(confusion_matrix)
print("\nOverall Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Confusion Matrix:
# [[2, 41], [1, 60]]
#
# Overall Accuracy: 59.62%

# %% [markdown]
# The correct overall accuracy for the logistic regression model with Lag2 as the predictor on the held-out data is approximately 59.62%.

# %% [markdown]
# #### e)Repeat (d) using LDA.

# %%
# BEGIN SOLUTION

# Filter the data for the training period (1990 to 2008)
train_data = data[data['Year'] <= 2008]

# Filter the data for the test period (2009 and 2010)
test_data = data[data['Year'] >= 2009]

# Create the design matrix with Lag2 as the predictor for training data
X_train = train_data[['Lag2']]
y_train = train_data['Direction']

# Create the LDA model and fit it to the training data
lda_model = LinearDiscriminantAnalysis()
lda_model.fit(X_train, y_train)

# Prepare the design matrix for the test data
X_test = test_data[['Lag2']]

# END SOLUTION

# %%
# BEGIN SOLUTION

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# Make predictions on the test data
predictions = lda_model.predict(X_test)

# Create the confusion matrix
cm = confusion_matrix(test_data['Direction'], predictions)

print("Confusion Matrix:")
print(cm)

# Compute the classification report
report = classification_report(test_data['Direction'], predictions)

print("\n\nClassification Report:")
print(report)

# Calculate the overall accuracy
accuracy = accuracy_score(test_data['Direction'], predictions)

# END SOLUTION
# Out:
# Confusion Matrix:
# [[ 9 34]
#  [ 5 56]]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.21      0.32        43
#          1.0       0.62      0.92      0.74        61
#
#     accuracy                           0.62       104
#    macro avg       0.63      0.56      0.53       104
# weighted avg       0.63      0.62      0.57       104

# %%
# BEGIN SOLUTION

# Create a custom color palette
cmap = sns.light_palette("purple", as_cmap=True)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, cmap=cmap, fmt="d", cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix (LDA)', fontsize=14)
plt.show()

# Calculate the overall accuracy
accuracy = accuracy_score(test_data['Direction'], predictions)
print("\nOverall Accuracy (LDA): {:.2f}%".format(accuracy * 100))

# END SOLUTION
# Out:
# Overall Accuracy (LDA): 62.50%

# %% [markdown]
# The interpretation of the confusion matrix:
#
# True Positives (TP) = 56 False Positives (FP) = 34 False Negatives (FN) = 5 True Negatives (TN) = 9
#
# Now, let's compute the overall fraction of correct predictions (accuracy):

# %%
# Given confusion matrix
confusion_matrix = [[9, 34], [5, 56]]

# Calculate overall accuracy
TN, FP, FN, TP = confusion_matrix[0][0], confusion_matrix[0][1], confusion_matrix[1][0], confusion_matrix[1][1]
total_predictions = TP + FP + FN + TN
accuracy = (TP + TN) / total_predictions

print("Confusion Matrix:")
print(confusion_matrix)
print("\nOverall Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Confusion Matrix:
# [[9, 34], [5, 56]]
#
# Overall Accuracy: 62.50%

# %% [markdown]
# The overall accuracy for the held-out data (data from 2009 and 2010) is approximately 62.50%.

# %% [markdown]
# #### f) Repeat (d) using QDA.

# %%
# BEGIN SOLUTION

# Filter the data for the training period (1990 to 2008)
train_data = data[data['Year'] <= 2008]

# Filter the data for the test period (2009 and 2010)
test_data = data[data['Year'] >= 2009]

# Create the design matrix with Lag2 as the predictor for training data
X_train = train_data[['Lag2']]
y_train = train_data['Direction']

# Create the QDA model and fit it to the training data
qda_model = QuadraticDiscriminantAnalysis()
qda_model.fit(X_train, y_train)

# Prepare the design matrix for the test data
X_test = test_data[['Lag2']]

# END SOLUTION

# %%
# BEGIN SOLUTION

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# Make predictions on the test data
predictions = qda_model.predict(X_test)

# Create the confusion matrix
cm = confusion_matrix(test_data['Direction'], predictions)

print("Confusion Matrix:")
print(cm)

# Compute the classification report
report = classification_report(test_data['Direction'], predictions)

print("\n\nClassification Report:")
print(report)

# Calculate the overall accuracy
accuracy = accuracy_score(test_data['Direction'], predictions)
# END SOLUTION
# Out:
# Confusion Matrix:
# [[ 0 43]
#  [ 0 61]]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        43
#          1.0       0.59      1.00      0.74        61
#
#     accuracy                           0.59       104
#    macro avg       0.29      0.50      0.37       104
# weighted avg       0.34      0.59      0.43       104
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# BEGIN SOLUTION

# Create a custom color palette
cmap = sns.light_palette("blue", as_cmap=True)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, cmap=cmap, fmt="d", cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix (QDA)', fontsize=14)
plt.show()

# Calculate the overall accuracy
accuracy = accuracy_score(test_data['Direction'], predictions)
print("\nOverall Accuracy (QDA): {:.2f}%".format(accuracy * 100))

# END SOLUTION
# Out:
# Overall Accuracy (QDA): 58.65%

# %% [markdown]
# The interpretation of the confusion matrix:
#
# True Positives (TP) = 61 False Positives (FP) = 43 False Negatives (FN) = 0 True Negatives (TN) = 0
#
# Now, let's compute the overall fraction of correct predictions (accuracy):

# %%
# Given confusion matrix
confusion_matrix = [[0, 43], [0, 61]]

# Calculate overall accuracy
TN, FP, FN, TP = confusion_matrix[0][0], confusion_matrix[0][1], confusion_matrix[1][0], confusion_matrix[1][1]
total_predictions = TP + FP + FN + TN
accuracy = (TP + TN) / total_predictions

print("Confusion Matrix:")
print(confusion_matrix)
print("\nOverall Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Confusion Matrix:
# [[0, 43], [0, 61]]
#
# Overall Accuracy: 58.65%

# %% [markdown]
# The overall accuracy for the held-out data (data from 2009 and 2010) is approximately 58.65%.

# %% [markdown]
# #### g) Repeat (d) using KNN with K=1

# %%
# BEGIN SOLUTION

# Filter the data for the training period (1990 to 2008)
train_data = data[data['Year'] <= 2008]

# Filter the data for the test period (2009 and 2010)
test_data = data[data['Year'] >= 2009]

# Create the design matrix with Lag2 as the predictor for training data
X_train = train_data[['Lag2']]
y_train = train_data['Direction']

# Create the KNN model with K=1 and fit it to the training data
knn_model = KNeighborsClassifier(n_neighbors=1)
knn_model.fit(X_train, y_train)

# Prepare the design matrix for the test data
X_test = test_data[['Lag2']]

# END SOLUTION

# %%
# BEGIN SOLUTION

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# Make predictions on the test data
predictions = knn_model.predict(X_test)

# Create the confusion matrix
cm = confusion_matrix(test_data['Direction'], predictions)

print("Confusion Matrix:")
print(cm)

# Compute the classification report
report = classification_report(test_data['Direction'], predictions)

print("\n\nClassification Report:")
print(report)

# END SOLUTION
# Out:
# Confusion Matrix:
# [[22 21]
#  [32 29]]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.41      0.51      0.45        43
#          1.0       0.58      0.48      0.52        61
#
#     accuracy                           0.49       104
#    macro avg       0.49      0.49      0.49       104
# weighted avg       0.51      0.49      0.49       104

# %%
# BEGIN SOLUTION

# Create a custom color palette
cmap = sns.light_palette("purple", as_cmap=True)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, cmap=cmap, fmt="d", cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix (KNN with K=1)', fontsize=14)
plt.show()

# Calculate the overall accuracy
accuracy = accuracy_score(test_data['Direction'], predictions)
print("\nOverall Accuracy (KNN with K=1): {:.2f}%".format(accuracy * 100))

# END SOLUTION
# Out:
# Overall Accuracy (KNN with K=1): 49.04%

# %% [markdown]
# The interpretation of the confusion matrix:
#
# True Positives (TP) = 29 False Positives (FP) = 21 False Negatives (FN) = 32 True Negatives (TN) = 22
#
# Now, let's compute the overall fraction of correct predictions (accuracy):

# %%
# Given confusion matrix
confusion_matrix = [[22, 21], [32, 29]]

# Calculate overall accuracy
TN, FP, FN, TP = confusion_matrix[0][0], confusion_matrix[0][1], confusion_matrix[1][0], confusion_matrix[1][1]
total_predictions = TP + FP + FN + TN
accuracy = (TP + TN) / total_predictions

print("Confusion Matrix:")
print(confusion_matrix)
print("\nOverall Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Confusion Matrix:
# [[22, 21], [32, 29]]
#
# Overall Accuracy: 49.04%

# %% [markdown]
# The overall accuracy for the held-out data (data from 2009 and 2010) is approximately 49.04%.

# %% [markdown]
# #### h) Which of these methods appears to provide the best results on this data?

# %% [markdown]
# Answer: Provide your answer in this Markdown cell
#
# To determine which method provides the best results on this data, we should consider the overall accuracy and compare the performance of each method based on the confusion matrices.
#
# - Logistic Regression Model:
#
# Overall Accuracy: 59.62%
# Confusion Matrix: [[2, 41], [1, 60]]
#
# - LDA (Linear Discriminant Analysis):
#
# Overall Accuracy: 62.50%
# Confusion Matrix: [[9, 34], [5, 56]]
#
# - QDA (Quadratic Discriminant Analysis):
#
# Overall Accuracy: 58.65%
# Confusion Matrix: [[0, 43], [0, 61]]
#
# - KNN with K=1 (K-Nearest Neighbors with K=1):
#
# Overall Accuracy: 49.04%
# Confusion Matrix: [[22, 21], [32, 29]]
#
# Based on the overall accuracy and the confusion matrices, it appears that LDA (Linear Discriminant Analysis) provides the best results on this data with an overall accuracy of 62.50%. LDA has correctly classified a higher number of instances compared to the other methods, as evidenced by the confusion matrix where it has a relatively higher number of true positives and true negatives, and lower false positives and false negatives. This suggests that LDA is better suited for this particular dataset compared to Logistic Regression, QDA, and KNN with K=1.

# %% [markdown]
# ### 5) Develop a model to predict whether a given car gets high or low gas mileage based on the `Auto` data set. Load the dataset:

# %%
# BEGIN SOLUTION
#Load dataset

data = sm.datasets.get_rdataset('Auto', 'ISLR').data

# Print the first few rows of the dataset to inspect its structure
data.head()

# END SOLUTION
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 1  18.0          8         307.0         130    3504          12.0    70
# 2  15.0          8         350.0         165    3693          11.5    70
# 3  18.0          8         318.0         150    3436          11.0    70
# 4  16.0          8         304.0         150    3433          12.0    70
# 5  17.0          8         302.0         140    3449          10.5    70
#
#    origin                       name
# 1       1  chevrolet chevelle malibu
# 2       1          buick skylark 320
# 3       1         plymouth satellite
# 4       1              amc rebel sst
# 5       1                ford torino

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 1 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    int64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   year          392 non-null    int64
#  7   origin        392 non-null    int64
#  8   name          392 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 30.6+ KB

# %%
data.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %% [markdown]
# a) Create a binary variable, `mpg01`, that contains a `1` if `mpg` contains a value above its median, and a `0` if `mpg` contains a value below its median.Note : you may find it helpful to use the `pd.DataFrame()` function to create a single data set containing both `mpg01` and the other `Auto` variables.
#
# Link to median():
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.median.html

# %%
# BEGIN SOLUTION

# Calculate the median of the 'mpg' column
mpg_median = data['mpg'].median()

print("Median is: ", mpg_median, "\n")

# Create the binary variable 'mpg01'
data['mpg01'] = (data['mpg'] > mpg_median).astype(int)

# Display the first few rows of the updated dataset
data.head()

# END SOLUTION
# Out:
# Median is:  22.75
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 1  18.0          8         307.0         130    3504          12.0    70
# 2  15.0          8         350.0         165    3693          11.5    70
# 3  18.0          8         318.0         150    3436          11.0    70
# 4  16.0          8         304.0         150    3433          12.0    70
# 5  17.0          8         302.0         140    3449          10.5    70
#
#    origin                       name  mpg01
# 1       1  chevrolet chevelle malibu      0
# 2       1          buick skylark 320      0
# 3       1         plymouth satellite      0
# 4       1              amc rebel sst      0
# 5       1                ford torino      0

# %% [markdown]
# #### b) Explore the data graphically in order to investigate the association between `mpg01` and the other features. Which of the other features seem most likely to be useful in predicting `mpg01`? Scatterplots and boxplots may be useful tools to answer this question Describe your findings
#
# Link to Scatter plot: https://seaborn.pydata.org/generated/seaborn.scatterplot.html
#
# Link to Violin plot: https://seaborn.pydata.org/generated/seaborn.violinplot.html
#
# Link to Box plot: https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %%
# BEGIN SOLUTION

# Create scatter plots for selected features
selected_features = ['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin']
for feature in selected_features:
    sns.scatterplot(data=data, x=feature, y='mpg01')
    plt.title(f'Scatter Plot of {feature} vs. mpg01')
    plt.show()


# END SOLUTION

# %% [markdown]
# Based on the scatter plots here is the analysis -
#
# - It is difficult to predict with features like cylinders, year and origin as the plot shows same values for mpg01 as '0' below median mpg and '1' above median mpg.
#
# - Incase of displacement and horsepower for the automobiles with a decrease there is a clear increase in mpg01 which is more fuel-efficient.
#
# - Incase of weight the lighter automobiles have higher fuel efficiency.
#
# - Incase of acceleration we are able to find a marginal positive correlation with mpg01.
#
# So according to the above observations we are finding the three features displacement, horsepower, weight and acceleration are most likely to be useful in predicting mpg01.

# %%
# BEGIN SOLUTION

# Create violin plots for selected features
for feature in selected_features:
    sns.violinplot(data=data, x='mpg01', y=feature)
    plt.title(f'Violin Plot of {feature} vs. mpg01')
    plt.show()

# END SOLUTION

# %% [markdown]
# Based on the violin plots, here are the features that seem most likely to be useful in predicting mpg01 (fuel efficiency):
#
# - Number of cylinders: There is a clear trend of increasing fuel efficiency with decreasing number of cylinders. Cars with 4 cylinders have the highest fuel efficiency, while cars with 8 cylinders have the lowest fuel efficiency.
# - Displacement: There is a general trend of decreasing fuel efficiency with increasing displacement. Cars with lower displacement have higher fuel efficiency, while cars with higher displacement have lower fuel efficiency.
# - Horsepower: There is a general trend of decreasing fuel efficiency with increasing horsepower. Cars with less horsepower have more fuel efficiency.
# - Weight: There is a general trend of decreasing fuel efficiency with increasing weight. Cars with lower weight have higher fuel efficiency, while cars with higher weight have lower fuel efficiency.
# - Year: There is a general trend of increasing fuel efficiency with increasing year. Cars from newer years tend to have higher fuel efficiency than cars from older years.
#
# These features are all related to the physical characteristics of a car, and they can all affect the car's fuel efficiency. For example, cars with fewer cylinders have smaller engines, which are lighter and more fuel-efficient. Cars with lower displacement also have smaller engines, which are lighter and more fuel-efficient. Cars which have low horsepower are more fuel efficient. Cars with lower weight are also more fuel-efficient, because they require less energy to move. And cars from newer years tend to have more fuel-efficient engines, because of advances in engine technology.

# %%
# BEGIN SOLUTION

# Create box plots for selected features
for feature in selected_features:
    sns.boxplot(data=data, x='mpg01', y=feature)
    plt.title(f'Box Plot of {feature} vs. mpg01')
    plt.show()

# END SOLUTION

# %% [markdown]
# Here are the findings -
#
# Boxplots are made to compare the overall distributions for each of the quantitative variables between cars with mpg01 values '0' that is below-median and '1' that is above-median.
#
# - For cylinders, we see that aside from some outliers, the majority of cars with above-median mpg have four-cylinder engines.
#
# - For displacement, at least 75% of the cars with above-median mpg have smaller engines than 75% of the cars with below-median mpg.
#
# - This is also true for horsepower and weight.
#
# - For acceleration and manufacture year, while there are definitely differences between cars with above-median mpg and those with below-median mpg, the differences aren't as strong compared to the first four predictors.
#
# - In particular, there is a lot more overlap in both time to reach 60 mpg and manufacture year between the two categories of cars, whereas for the other predictors there is almost no overlap for the boxplots between the two categories.
#
# - This suggests that cylinders, displacement, horsepower, and weight will be the most useful in predicting mpg01.

# %%
# Create a pairplot for selected numeric features
sns.pairplot(data,height=1.10)
plt.show()

# %% [markdown]
# We have shown a pair plot which shows the whole picture of correlation for all the predictors including mpg01 for the entire dataframe. Referring to correlation between mpg and other variables it provides a good comparison for the analysis of selection of most useful features in predicting mpg01.

# %%
# Correlation heatmap
correlation_matrix = data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-49-ecb5bfc51886>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %% [markdown]
# Key observations from the correlation matrix:
#
# 'mpg01' has a strong negative correlation with 'cylinders', 'displacement', 'weight': The correlation coefficients are -0.759194, -0.753477 and -0.757757, respectively. This suggests that as the number of cylinders, engine displacement and weight increases, the fuel efficiency ('mpg01') tends to decrease.
#
# 'mpg01'has a moderate negative correlation with 'horsepower' : The correlation coefficient is -0.67. This indicates that as horsepower increases the fuel efficiency ('mpg01') tends to decrease.
#
# 'mpg01' has a moderate positive correlation with 'year' and 'origin': The correlation coefficients are 0.429904 and 0.513698, respectively. This indicates that newer cars (higher 'year') and cars from certain origins tend to have higher fuel efficiency.
#
# Other correlations: The correlations between 'mpg01' and 'acceleration' (0.346822) with other features are also present, but not as strong as the associations mentioned above.
#
# Overall, the correlation matrix confirms the initial findings from the exploratory analysis. Features like 'cylinders', 'displacement' and 'weight' seem most associated with the target variable 'mpg01' as this has strongest correlation. These features are likely to be useful in predicting fuel efficiency ('mpg01') in the 'Auto' dataset.

# %% [markdown]
# #### C) Split the data into a training set and a test set (70%, 30%). Use `random.seed(4)` to make the training data reproducible.
#
# Link to linear model: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
# BEGIN SOLUTION

# Specify the features and target variable

X = data.drop(columns=['mpg01', 'name', 'mpg'])
y = data['mpg01']

# Split the data into a training set and a test set (70%, 30%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=4)

# Display the shapes of the resulting sets to verify the split
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)

# END SOLUTION
# Out:
# X_train shape: (274, 7)
# X_test shape: (118, 7)
# y_train shape: (274,)
# y_test shape: (118,)

# %% [markdown]
# #### d) Perform LDA on the training data in order to predict `mpg01` using the variables that seemed most associated with `mpg01` in (b). What is the test error of the model obtained?

# %% [markdown]
# Based on (b) the features taken based on Heat map is taken as they have the most strongest correlation with mpg01.

# %%
# BEGIN SOLUTION

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score

# END SOLUTION

# %%
# BEGIN SOLUTION

# Specify the selected features considering all the plots in (b)
selected_features = ['cylinders', 'displacement', 'weight']

# END SOLUTION

# %%
# BEGIN SOLUTION

# Create the LDA model and fit it to the training data
lda_model = LinearDiscriminantAnalysis()
lda_model.fit(X_train[selected_features], y_train)

# END SOLUTION
# Out:
# LinearDiscriminantAnalysis()

# %%
# BEGIN SOLUTION

# Make predictions on the test data
predictions = lda_model.predict(X_test[selected_features])

# END SOLUTION

# %%
# BEGIN SOLUTION

# Evaluate the LDA model
accuracy = accuracy_score(y_test, predictions)
print(f"LDA Accuracy: {accuracy * 100:.2f}%\n\n")

# Additional evaluation metrics (optional)
print("Classification Metrics - \n\n", classification_report(y_test, predictions))

# Calculate the test error as (1 - test accuracy)
test_error = 1 - accuracy

# Print the test error as a percentage
print(f"\nLDA Test Error: {test_error * 100:.2f}%")

# END SOLUTION
# Out:
# LDA Accuracy: 88.14%
#
#
# Classification Metrics -
#
#                precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89        65
#            1       0.85      0.89      0.87        53
#
#     accuracy                           0.88       118
#    macro avg       0.88      0.88      0.88       118
# weighted avg       0.88      0.88      0.88       118
#
#
# LDA Test Error: 11.86%

# %% [markdown]
# In this code, the LDA model is created and fitted to the training data using the selected features from part (b). The model's predictions are then made on the test data, and the test error is calculated as 1 minus the accuracy score. The test error provides an indication of how well the LDA model performs on the test set.

# %% [markdown]
# The "LDA Test Error" line provides the test error value, which is 11.86%. This means that out of the total test samples, approximately 11.86% were misclassified by the Linear Discriminant Analysis (LDA) model. The lower the test error, the better the model's performance on the test data.

# %% [markdown]
# #### e) Perform QDA on the training data in order to predict `mpg01` using the variables that seemed most associated with `mpg01` in (b). What is the test error of the model obtained?

# %%
# BEGIN SOLUTION

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# END SOLUTION

# %%
# BEGIN SOLUTION

# Create the QDA model and fit it to the training data
qda_model = QuadraticDiscriminantAnalysis()
qda_model.fit(X_train[selected_features], y_train)

# Make predictions on the test data
predictions = qda_model.predict(X_test[selected_features])

# END SOLUTION

# %%
# BEGIN SOLUTION

# Evaluate the QDA model
test_accuracy_qda = accuracy_score(y_test, predictions)
print(f"QDA Accuracy: {test_accuracy_qda * 100:.2f}%\n\n")

# Additional evaluation metrics (optional)
print("Classification Metrics - \n\n",classification_report(y_test, predictions))

# Calculate the test error as (1 - test accuracy) and print it as a percentage
test_error_qda = 1 - test_accuracy_qda
print(f"QDA Test Error: {test_error_qda * 100:.2f}%")

# END SOLUTION
# Out:
# QDA Accuracy: 88.98%
#
#
# Classification Metrics -
#
#                precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90        65
#            1       0.92      0.83      0.87        53
#
#     accuracy                           0.89       118
#    macro avg       0.89      0.88      0.89       118
# weighted avg       0.89      0.89      0.89       118
#
# QDA Test Error: 11.02%

# %% [markdown]
# In this code, the QDA model is created and fitted to the training data using the selected features from part (b). The model's predictions are then made on the test data, and the test error is calculated as 1 minus the accuracy score. The test error provides an indication of how well the QDA model performs on the test set.

# %% [markdown]
# The "QDA Test Error" line provides the test error value, which is 11.02%. This means that out of the total test samples, approximately 11.02% were misclassified by the Quadratic Discriminant Analysis (QDA) model. As with any classification model, lower test error values indicate better performance on the test data.

# %% [markdown]
# #### f) Perform logistic regression on the training data in order to predict `mpg01` using the variables that seemed most associated with `mpg01` in (b). What is the test error of the model obtained?
#
# Link to linear model: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

# %%
# BEGIN SOLUTION

from sklearn.linear_model import LogisticRegression

# END SOLUTION

# %%
# BEGIN SOLUTION

# Create the logistic regression model and fit it to the training data
logit_model = LogisticRegression()
logit_model.fit(X_train[selected_features], y_train)

# Make predictions on the test data
predictions = logit_model.predict(X_test[selected_features])

# END SOLUTION

# %%
# BEGIN SOLUTION

# Evaluate the Logistic Regression model
test_accuracy_logreg = accuracy_score(y_test, predictions)
print(f"LR Accuracy: {test_accuracy_logreg * 100:.2f}%\n\n")

# Additional evaluation metrics (optional)
print("Classification Metrics - \n\n", classification_report(y_test, predictions))

# Calculate the test error as (1 - test accuracy) and print it as a percentage
test_error_logreg = 1 - test_accuracy_logreg
print(f"Logistic Regression Test Error: {test_error_logreg * 100:.2f}%")

# END SOLUTION
# Out:
# LR Accuracy: 87.29%
#
#
# Classification Metrics -
#
#                precision    recall  f1-score   support
#
#            0       0.88      0.89      0.89        65
#            1       0.87      0.85      0.86        53
#
#     accuracy                           0.87       118
#    macro avg       0.87      0.87      0.87       118
# weighted avg       0.87      0.87      0.87       118
#
# Logistic Regression Test Error: 12.71%

# %% [markdown]
# In this code, the logistic regression model is created and fitted to the training data using the selected features from part (b). The model's predictions are then made on the test data, and the test error is calculated as 1 minus the accuracy score. The test error provides an estimate of how well the logistic regression model performs on the test set.

# %% [markdown]
# The "Logistic Regression Test Error" line provides the test error value, which is 12.71%. This means that out of the total test samples, approximately 12.71% were misclassified by the Logistic Regression model. As with any classification model, lower test error values indicate better performance on the test data.

# %% [markdown]
# Among the three models presented (Linear Discriminant Analysis - LDA, Quadratic Discriminant Analysis - QDA, and Logistic Regression), the model with the lowest test error is the best performer on the test data. In your case, the test error values are as follows:
#
# - LDA Test Error: 11.86%
# - QDA Test Error: 11.02%
# - Logistic Regression Test Error: 12.71%
#
# Based on these test error values, the Quadratic Discriminant Analysis (QDA) model has the lowest test error, followed by the Linear Discriminant Analysis (LDA) model, and then the Logistic Regression model. Therefore, among these three models, the QDA model is performing the best on the given test data. Lower test error indicates better generalization and prediction performance on unseen data.

# %%
# !pip install nbconvert

# %%
# !jupyter nbconvert --to html /content/IML_Week_4_Assignment_Learner_template.ipynb
